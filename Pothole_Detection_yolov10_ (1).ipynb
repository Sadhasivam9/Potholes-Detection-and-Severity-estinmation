# %%
# !git clone https://github.com/THU-MIG/yolov10.git
# Out:
# Cloning into 'yolov10'...
# remote: Enumerating objects: 20294, done.
# remote: Counting objects: 100% (373/373), done.
# remote: Compressing objects: 100% (177/177), done.
# remote: Total 20294 (delta 251), reused 303 (delta 196), pack-reused 19921
# Receiving objects: 100% (20294/20294), 11.37 MiB | 19.37 MiB/s, done.
# Resolving deltas: 100% (14230/14230), done.

# %%
cd yolov10
# Out:
# /content/yolov10

# %%
pip install .
# Out:
# Processing /content/yolov10
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...

# %%
import os
import urllib.request
weights_dir = os.path.join(os.getcwd(), "weights")
os.makedirs(weights_dir, exist_ok=True)

urls = [

"https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10n.pt",

"https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10s.pt",

"https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10m.pt",

"https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10b.pt",

"https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10x.pt",

"https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10l.pt"
]

# Download each file

for url in urls:

  file_name = os.path.join(weights_dir, os.path.basename(url))
  urllib.request.urlretrieve(url, file_name)

  print(f"Downloaded {file_name}")
# Out:
# Downloaded /content/yolov10/weights/yolov10n.pt
# Downloaded /content/yolov10/weights/yolov10s.pt
# Downloaded /content/yolov10/weights/yolov10m.pt
# Downloaded /content/yolov10/weights/yolov10b.pt
# Downloaded /content/yolov10/weights/yolov10x.pt
# Downloaded /content/yolov10/weights/yolov10l.pt

# %%
#to test
#!yolo task=detect mode=predict conf=0.25 save=True model=../weights/yolov10n.pt source=/content/test_images/Avalum_Nanum.jpeg
# Out:
# Ultralytics YOLOv8.1.34 🚀 Python-3.10.12 torch-2.3.0+cu121 CPU (Intel Xeon 2.20GHz)
# YOLOv10n summary (fused): 285 layers, 2762608 parameters, 63840 gradients, 8.6 GFLOPs
#
# image 1/1 /content/test_images/Avalum_Nanum.jpeg: 640x640 2 0s, 277.0ms
# Speed: 18.5ms preprocess, 277.0ms inference, 26.7ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
from google.colab import files

# Upload the zipped file
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ebf44cbf-6d74-456b-95e7-e314d22d9f5b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ebf44cbf-6d74-456b-95e7-e314d22d9f5b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import zipfile
import os

# Get the uploaded file name
zip_file_name = next(iter(uploaded.keys()))

# Unzip the file
with zipfile.ZipFile(zip_file_name, 'r') as zip_ref:
    zip_ref.extractall('/content/custom_datasets')

# Verify the folder structure
print(os.listdir('/content/custom_datasets'))
# Out:
# ['dataset_final']

# %%
# !yolo task=detect mode=train epochs=90 batch=16 plots=True model=weights/yolov10n.pt data="/content/data.yaml"
# Out:
# New https://pypi.org/project/ultralytics/8.2.31 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.1.34 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
import shutil

# Replace 'your_folder_name' with the path to your folder
shutil.make_archive('model_output', 'zip', '/content/yolov10/runs/detect')
# Out:
# '/content/yolov10/model_output.zip'

# %%
from google.colab import files

# Download the zipped folder
files.download('model_output.zip')

# %%
# !yolo task=detect mode=predict conf=0.25 save=True model=/content/yolov10/runs/detect/train3/weights/best.pt source= /content/test_images/2.jpg
# Out:
# Ultralytics YOLOv8.1.34 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv10n summary (fused): 285 layers, 2695586 parameters, 0 gradients, 8.2 GFLOPs
#
# image 1/1 /content/test_images/2.jpg: 640x640 1 moderate, 15.9ms
# Speed: 4.8ms preprocess, 15.9ms inference, 172.7ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo task=detect mode=predict conf=0.25 save=True model=/content/yolov10/runs/detect/train3/weights/best.pt source= /content/test_images/pothole_video.mp4
# Out:
# Ultralytics YOLOv8.1.34 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv10n summary (fused): 285 layers, 2695586 parameters, 0 gradients, 8.2 GFLOPs
#
# video 1/1 (frame 1/692) /content/test_images/pothole_video.mp4: 384x640 3 severes, 94.6ms
# video 1/1 (frame 2/692) /content/test_images/pothole_video.mp4: 384x640 2 severes, 10.8ms
# video 1/1 (frame 3/692) /content/test_images/pothole_video.mp4: 384x640 2 severes, 12.7ms
# video 1/1 (frame 4/692) /content/test_images/pothole_video.mp4: 384x640 2 severes, 9.9ms
# video 1/1 (frame 5/692) /content/test_images/pothole_video.mp4: 384x640 3 severes, 10.8ms
# video 1/1 (frame 6/692) /content/test_images/pothole_video.mp4: 384x640 1 severe, 1 moderate, 10.9ms
# video 1/1 (frame 7/692) /content/test_images/pothole_video.mp4: 384x640 2 severes, 1 moderate, 10.3ms
# video 1/1 (frame 8/692) /content/test_images/pothole_video.mp4: 384x640 2 severes, 2 moderates, 9.5ms
# ...

# %%
# !yolo task=detect mode=predict conf=0.25 save=True model=/content/yolov10/runs/detect/train3/weights/best.pt source=/content/test_images/video2.mp4
# Out:
# Ultralytics YOLOv8.1.34 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv10n summary (fused): 285 layers, 2695586 parameters, 0 gradients, 8.2 GFLOPs
#
# video 1/1 (frame 1/1955) /content/test_images/video2.mp4: 384x640 (no detections), 102.6ms
# video 1/1 (frame 2/1955) /content/test_images/video2.mp4: 384x640 (no detections), 11.3ms
# video 1/1 (frame 3/1955) /content/test_images/video2.mp4: 384x640 (no detections), 10.5ms
# video 1/1 (frame 4/1955) /content/test_images/video2.mp4: 384x640 (no detections), 10.3ms
# video 1/1 (frame 5/1955) /content/test_images/video2.mp4: 384x640 (no detections), 10.9ms
# video 1/1 (frame 6/1955) /content/test_images/video2.mp4: 384x640 (no detections), 10.3ms
# video 1/1 (frame 7/1955) /content/test_images/video2.mp4: 384x640 (no detections), 12.4ms
# video 1/1 (frame 8/1955) /content/test_images/video2.mp4: 384x640 (no detections), 14.3ms
# ...

# %%
# !yolo task=detect mode=predict conf=0.25 save=True model=/content/yolov10/runs/detect/train3/weights/best.pt source=/content/test_images/3487913239-preview.mp4
# Out:
# Ultralytics YOLOv8.1.34 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv10n summary (fused): 285 layers, 2695586 parameters, 0 gradients, 8.2 GFLOPs
#
# video 1/1 (frame 1/120) /content/test_images/3487913239-preview.mp4: 384x640 2 severes, 114.0ms
# video 1/1 (frame 2/120) /content/test_images/3487913239-preview.mp4: 384x640 3 severes, 11.0ms
# video 1/1 (frame 3/120) /content/test_images/3487913239-preview.mp4: 384x640 3 severes, 9.5ms
# video 1/1 (frame 4/120) /content/test_images/3487913239-preview.mp4: 384x640 2 severes, 10.0ms
# video 1/1 (frame 5/120) /content/test_images/3487913239-preview.mp4: 384x640 2 severes, 9.4ms
# video 1/1 (frame 6/120) /content/test_images/3487913239-preview.mp4: 384x640 2 severes, 11.2ms
# video 1/1 (frame 7/120) /content/test_images/3487913239-preview.mp4: 384x640 2 severes, 9.3ms
# video 1/1 (frame 8/120) /content/test_images/3487913239-preview.mp4: 384x640 3 severes, 9.4ms
# ...
